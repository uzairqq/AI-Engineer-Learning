# %% [markdown]
# <a href="https://colab.research.google.com/github/uzairqq/AI-Engineer-Learning/blob/main/Lecture_03_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basics Of Python
print("Python")
print("Hello Python") # This is Print Method
# Out:
# Python
# Hello Python

# %%
"Hello"
# Out:
# 'Hello'

# %%
'Hello'
# Out:
# 'Hello'

# %%
print('He said "I Can DO It" ')
# Out:
# He said "I Can DO It"

# %%
print(r"C:\user\older")
# Out:
# C:\user\older

# %%
print("C:/user/older")
# Out:
# C:/user/older

# %%
"print"
# Out:
# 'print'

# %%
print("Addition:",5+3)
# Out:
# Addition: 8

# %%
print("Subtraction:",5-3)
# Out:
# Subtraction 2

# %%
print("Multiplication:",5*2)
# Out:
# Multiplication: 10

# %%
print("Division:", 5/2)
# Out:
# Division: 2.5

# %%
print("Floor Division:", 5//2)
# Out:
# Floor Division: 2

# %%
print("Modulus:", 5%2)
# Out:
# Modulus: 1

# %%
print("Expontiation:",5**3)
# Out:
# Expontiation: 125

# %%
5+4-2
# Out:
# 7

# %%
5+4-
# Out:
#   File "/tmp/ipykernel_3335/4093583566.py", line 1
#     5+4- #Here It Will Error Come
#          ^
# SyntaxError: invalid syntax
