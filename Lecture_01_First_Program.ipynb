# %% [markdown]
# <a href="https://colab.research.google.com/github/uzairqq/AI-Engineer-Learning/blob/main/Lecture_01_First_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Yes I Can Learn Python")
# Out:
# Yes I Can Learn Python

# %%
print(123)
# Out:
# 123

# %%
7
# Out:
# 7

# %%
3+4|
# Out:
#   File "/tmp/ipykernel_2634/3683767136.py", line 1
#     3+4|
#         ^
# SyntaxError: invalid syntax

# %%
3+3
# Out:
# 6

# %%
5-2
# Out:
# 3

# %%
4*5
# Out:
# 20

# %%
"Hello"
# Out:
# 'Hello'

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2634/3305111549.py in <cell line: 0>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %% [markdown]
# **Arithemetic Functions**

# %%
4*5
# Out:
# 20

# %%
10/2
# Out:
# 5.0
