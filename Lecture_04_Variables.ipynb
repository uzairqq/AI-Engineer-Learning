# %% [markdown]
# <a href="https://colab.research.google.com/github/uzairqq/AI-Engineer-Learning/blob/main/Lecture_04_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
id=1234
name="Uzair"
phone=+923333758131
print(2345)
# Out:
# 2345

# %%
print(id)
# Out:
# 1234

# %%
print(name)
# Out:
# Uzair

# %%
print(phone)
# Out:
# 923333758131

# %%
x=5
y=10
add=x+y
print(add)
# Out:
# 15

# %%
_x=45

# %%
print(_x)
# Out:
# 45

# %%
8x=45
# Out:
#   File "/tmp/ipykernel_24430/580750149.py", line 1
#     8x=45
#     ^
# SyntaxError: invalid decimal literal

# %%
x=56

# %%
print(x)
# Out:
# 56

# %%
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24430/2644917711.py in <cell line: 0>()
# ----> 1 print(Name)
#
# NameError: name 'Name' is not defined

# %%
print(name)
# Out:
# Uzair

# %%
print(NAME)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24430/1048088141.py in <cell line: 0>()
# ----> 1 print(NAME)
#
# NameError: name 'NAME' is not defined

# %%
name="Laraib"
print(name)
# Out:
# Laraib

# %%
name=input("Please Enter Your Name")
# Out:
# Please Enter Your Nameuzair

# %%
print(name)
# Out:
# uzair

# %%
name=input()
# Out:
# Iqbal

# %%
print(name)
# Out:
# Iqbal

# %%
name='Uzair '  + 'Iqbal'

# %%
print(name)
# Out:
# Uzair Iqbal

# %%
name='Python' + 3.14
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_24430/3183774743.py in <cell line: 0>()
# ----> 1 name='Python' + 3.14
#
# TypeError: can only concatenate str (not "float") to str

# %%
print(name[0])
# Out:
# U

# %%
print(name[4])
# Out:
# r

# %%
name="Uzair Iqbal"
age=33
city="Karachi"
print(name)
print(age)
print(city)
# Out:
# Uzair Iqbal
# 33
# Karachi

# %%
name=input("Enter Name")
age=input("Enter Age")
city=input("Enter City")
# Out:
# Enter NameAshar amjad
# Enter Age37
# Enter Citylahore

# %%
first_name=input("Enter First Name")
last_name=input("Enter Last Name")
full_name=first_name + ' ' + last_name
print(full_name)
# Out:
# Enter First Nameuzair
# Enter Last Nameiqbal
# uzair iqbal

# %%
print(name[0])
print(name[-1])
# Out:
# A
# d
